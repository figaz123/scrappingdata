# %% [markdown]
# <a href="https://colab.research.google.com/github/figaz123/scrappingdata/blob/main/Scrappingdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import shutil
import glob

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/scrapping data/gabungan'

# %%
os.chdir('/content/drive/MyDrive/scrapping data')

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/scrapping data'

# %%
os.listdir()
# Out:
# ['jakarta2.csv',
#  'jakarta3.csv',
#  'bandung1.csv',
#  'bandung2.csv',
#  'bandung3.csv',
#  'sby1.csv',
#  'sby2.csv',
#  'sby3.csv',
#  'medan1.csv',
#  'medan2.csv',
#  'medan3.csv',
#  'bali1.csv',
#  'bali2.csv',
#  'bali3.csv',
#  'lombok1.csv',
#  'lombok2.csv',
#  'lombok3.csv',
#  'semarang1.csv',
#  'semarang2.csv',
#  'semarang3.csv',
#  'jakarta1.csv',
#  'bali4.csv',
#  'bali5.csv',
#  'bali6.csv',
#  'bali7.csv',
#  'bali8.csv',
#  'bali9.csv',
#  'jakarta4.csv',
#  'jakarta5.csv',
#  'jakarta6.csv',
#  'jakarta7.csv',
#  'jakarta8.csv',
#  'jakarta9.csv',
#  'sby4.csv',
#  'sby5.csv',
#  'sby6.csv',
#  'sby7.csv',
#  'sby8.csv',
#  'sby9.csv',
#  'lombok4.csv',
#  'lombok5.csv',
#  'lombok6.csv',
#  'lombok7.csv',
#  'lombok8.csv',
#  'lombok9.csv',
#  'medan4.csv',
#  'medan5.csv',
#  'medan6.csv',
#  'medan7.csv',
#  'medan8.csv',
#  'medan9.csv',
#  'semarang4.csv',
#  'semarang5.csv',
#  'semarang6.csv',
#  'semarang7.csv',
#  'semarang8.csv',
# ...

# %%
test = 'jakarta1.csv'
test = pd.read_csv(test)
test.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.google.com/maps/place/Ragunan+Zoo/...
# 3  https://www.google.com/maps/place/Taman+Mini+I...
# 4  https://www.google.com/maps/place/Taman+Suropa...
#
#                        qBF1Pd  MW4etd      UY7F9 W4Efsd            W4Efsd 2  \
# 0                         NaN     NaN        NaN    NaN                 NaN
# 1                         NaN     NaN        NaN    NaN                 NaN
# 2                 Ragunan Zoo     4.5   (92,625)      ·  Tourist attraction
# 3  Taman Mini Indonesia Indah     4.6  (141,446)      ·  Tourist attraction
# 4              Taman Suropati     4.6   (18,364)      ·  Tourist attraction
#
#                                   W4Efsd 4  \
# 0                                      NaN
# 1                                      NaN
# 2                      Jl. Harsono RM No.1
# ...

# %%
test = 'bandung1.csv'
test = pd.read_csv(test)
test.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Dago+Dreampa...
# 2  https://www.google.com/maps/place/Taman+Hutan+...
# 3  https://www.google.com/maps/place/Tebing+Kerat...
# 4  https://www.google.com/maps/place/The+Great+As...
#
#                             qBF1Pd  MW4etd     UY7F9 W4Efsd  \
# 0                              NaN     NaN       NaN    NaN
# 1                   Dago Dreampark     4.2  (17,009)      ·
# 2  Taman Hutan Raya Ir. H. Djuanda     4.5  (14,193)      ·
# 3                   Tebing Keraton     4.5   (8,594)      ·
# 4            The Great Asia Africa     4.5  (13,675)      ·
#
#              W4Efsd 2                                  W4Efsd 4  \
# 0                 NaN                                       NaN
# 1  Tourist attraction          Jl. Dago Giri Km. 2.2 Mekarwangi
# 2  Tourist attraction  Kompleks Tahura, Jl. Ir. H. Juanda No.99
# ...

# %%
test = 'lombok1.csv'
test = pd.read_csv(test)
test.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Bukit+Merese...
# 2  https://www.google.com/maps/place/Wisata+di+Lo...
# 3  https://www.google.com/maps/place/Air+Terjun+B...
# 4  https://www.google.com/maps/place/Sade+Village...
#
#                                    qBF1Pd MW4etd    UY7F9 W4Efsd  \
# 0                                     NaN    NaN      NaN    NaN
# 1  Bukit Merese Lombok (Kuta Lombok Hill)    4,7  (5.116)      ·
# 2                        Wisata di Lombok    4,5    (113)      ·
# 3               Air Terjun Benang Kelambu    4,5  (1.880)      ·
# 4                            Sade Village    4,6  (6.400)      ·
#
#         W4Efsd 2                                     W4Efsd 4 W4Efsd 5  \
# 0            NaN                                          NaN      NaN
# 1  Tujuan Wisata                              Jl. Kuta Lombok        ·
# ...

# %%
test = 'medan1.csv'
test = pd.read_csv(test)
test.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/TAMAN+WISATA...
# 2  https://www.google.com/maps/place/Istana+Maimu...
# 3  https://www.google.com/maps/place/Taman+Sri+De...
# 4  https://www.google.com/maps/place/Upside+Down+...
#
#                                qBF1Pd MW4etd     UY7F9 W4Efsd       W4Efsd 2  \
# 0                                 NaN    NaN       NaN    NaN            NaN
# 1  TAMAN WISATA DANAU SIOMBAK MARELAN    3,9   (1.070)      ·  Tujuan Wisata
# 2          Istana Maimun, Kota Medan.    4,4  (17.337)      ·  Tujuan Wisata
# 3                      Taman Sri Deli    4,5   (1.480)      ·  Tujuan Wisata
# 4             Upside Down World Medan    4,3     (496)      ·  Tujuan Wisata
#
#                          W4Efsd 4 W4Efsd 5  \
# 0                             NaN      NaN
# 1         Jl. Ps. Nippon No.Ujung        ·
# 2      Jl. Brigjend Katamso No.66        ·
# ...

# %%
test = 'semarang1.csv'
test = pd.read_csv(test)
test.head()
# Out:
#                                          hfpxzc href              qBF1Pd  \
# 0                                                NaN                 NaN
# 1  https://www.google.com/maps/place/Lawang+Sewu/...         Lawang Sewu
# 2  https://www.google.com/maps/place/Kota+Lama+Se...  Kota Lama Semarang
# 3  https://www.google.com/maps/place/Puri+Maeroko...      Puri Maerokoco
# 4  https://www.google.com/maps/place/Brown+Canyon...        Brown Canyon
#
#   MW4etd     UY7F9 W4Efsd       W4Efsd 2  \
# 0    NaN       NaN    NaN            NaN
# 1    4,6  (61.396)      ·  Tujuan Wisata
# 2    4,7   (1.607)      ·  Tujuan Wisata
# 3    4,4   (3.881)      ·  Tujuan Wisata
# 4    4,2   (3.246)      ·  Tujuan Wisata
#
#                                    W4Efsd 4 W4Efsd 5  \
# 0                                       NaN      NaN
# 1                                Jl. Pemuda        ·
# 2                                       NaN      NaN
# 3                        Jl. Puri Anjasmoro        ·
# ...

# %%
test = 'bali1.csv'
test = pd.read_csv(test)
test.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Tegenungan+W...
# 2  https://www.google.com/maps/place/Mandala+Suci...
# 3  https://www.google.com/maps/place/Waterbom+Bal...
# 4  https://www.google.com/maps/place/Taman+Nasion...
#
#                       qBF1Pd MW4etd     UY7F9 W4Efsd       W4Efsd 2  \
# 0                        NaN    NaN       NaN    NaN            NaN
# 1       Tegenungan Waterfall    4,3  (21.592)      ·  Tujuan Wisata
# 2   Mandala Suci Wenara Wana    4,5  (34.238)      ·  Tujuan Wisata
# 3              Waterbom Bali    4,7   (9.939)      ·  Tujuan Wisata
# 4  Taman Nasional Bali Barat    4,5   (2.867)      ·  Tujuan Wisata
#
#                                  W4Efsd 4 W4Efsd 5  \
# 0                                     NaN      NaN
# 1                          Jl. Ir. Sutami        ·
# 2                       Jl. Monkey Forest        ·
# ...

# %%
directory = 'gabungan'
parent_dir = '/content/drive/MyDrive/scrapping data'
path = os.path.join(parent_dir, directory)
os.mkdir(path)
print("Direktori '%s'" % directory)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-222-a903b0416a53> in <module>()
#       2 parent_dir = '/content/drive/MyDrive/scrapping data'
#       3 path = os.path.join(parent_dir, directory)
# ----> 4 os.mkdir(path)
#       5 print("Direktori '%s'" % directory)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/scrapping data/gabungan'

# %%
gab_address = '/content/drive/MyDrive/scrapping data/gabungan'

# %%
os.listdir()
# Out:
# ['jakarta2.csv',
#  'jakarta3.csv',
#  'bandung1.csv',
#  'bandung2.csv',
#  'bandung3.csv',
#  'sby1.csv',
#  'sby2.csv',
#  'sby3.csv',
#  'medan1.csv',
#  'medan2.csv',
#  'medan3.csv',
#  'bali1.csv',
#  'bali2.csv',
#  'bali3.csv',
#  'lombok1.csv',
#  'lombok2.csv',
#  'lombok3.csv',
#  'semarang1.csv',
#  'semarang2.csv',
#  'semarang3.csv',
#  'jakarta1.csv',
#  'bali4.csv',
#  'bali5.csv',
#  'bali6.csv',
#  'bali7.csv',
#  'bali8.csv',
#  'bali9.csv',
#  'jakarta4.csv',
#  'jakarta5.csv',
#  'jakarta6.csv',
#  'jakarta7.csv',
#  'jakarta8.csv',
#  'jakarta9.csv',
#  'sby4.csv',
#  'sby5.csv',
#  'sby6.csv',
#  'sby7.csv',
#  'sby8.csv',
#  'sby9.csv',
#  'lombok4.csv',
#  'lombok5.csv',
#  'lombok6.csv',
#  'lombok7.csv',
#  'lombok8.csv',
#  'lombok9.csv',
#  'medan4.csv',
#  'medan5.csv',
#  'medan6.csv',
#  'medan7.csv',
#  'medan8.csv',
#  'medan9.csv',
#  'semarang4.csv',
#  'semarang5.csv',
#  'semarang6.csv',
#  'semarang7.csv',
#  'semarang8.csv',
# ...

# %%
files = glob.iglob(os.path.join(parent_dir, '*.csv'))

# %%
for file in files:
  if os.path.isfile(file):
    shutil.copy(file, gab_address)

# %%
os.listdir(gab_address)
# Out:
# ['gabungan_final',
#  'jakarta2.csv',
#  'sby3.csv',
#  'bandung2.csv',
#  'bandung3.csv',
#  'medan3.csv',
#  'bandung1.csv',
#  'medan1.csv',
#  'medan2.csv',
#  'jakarta3.csv',
#  'sby2.csv',
#  'sby1.csv',
#  'bali1.csv',
#  'bali3.csv',
#  'bali2.csv',
#  'lombok1.csv',
#  'semarang3.csv',
#  'lombok2.csv',
#  'semarang1.csv',
#  'lombok3.csv',
#  'jakarta1.csv',
#  'semarang2.csv',
#  'bali4.csv',
#  'bali5.csv',
#  'bali6.csv',
#  'bali9.csv',
#  'bali8.csv',
#  'bali7.csv',
#  'jakarta4.csv',
#  'jakarta5.csv',
#  'jakarta6.csv',
#  'jakarta7.csv',
#  'jakarta8.csv',
#  'jakarta9.csv',
#  'sby4.csv',
#  'sby6.csv',
#  'sby7.csv',
#  'sby5.csv',
#  'sby8.csv',
#  'sby9.csv',
#  'lombok4.csv',
#  'lombok5.csv',
#  'lombok6.csv',
#  'lombok7.csv',
#  'lombok8.csv',
#  'lombok9.csv',
#  'medan4.csv',
#  'medan5.csv',
#  'medan6.csv',
#  'medan8.csv',
#  'medan7.csv',
#  'medan9.csv',
#  'semarang4.csv',
#  'semarang6.csv',
#  'semarang5.csv',
#  'semarang8.csv',
# ...

# %%
os.chdir(gab_address)
os.getcwd()
# Out:
# '/content/drive/MyDrive/scrapping data/gabungan'

# %%
os.listdir()
# Out:
# ['gabungan_final',
#  'jakarta2.csv',
#  'sby3.csv',
#  'bandung2.csv',
#  'bandung3.csv',
#  'medan3.csv',
#  'bandung1.csv',
#  'medan1.csv',
#  'medan2.csv',
#  'jakarta3.csv',
#  'sby2.csv',
#  'sby1.csv',
#  'bali1.csv',
#  'bali3.csv',
#  'bali2.csv',
#  'lombok1.csv',
#  'semarang3.csv',
#  'lombok2.csv',
#  'semarang1.csv',
#  'lombok3.csv',
#  'jakarta1.csv',
#  'semarang2.csv',
#  'bali4.csv',
#  'bali5.csv',
#  'bali6.csv',
#  'bali9.csv',
#  'bali8.csv',
#  'bali7.csv',
#  'jakarta4.csv',
#  'jakarta5.csv',
#  'jakarta6.csv',
#  'jakarta7.csv',
#  'jakarta8.csv',
#  'jakarta9.csv',
#  'sby4.csv',
#  'sby6.csv',
#  'sby7.csv',
#  'sby5.csv',
#  'sby8.csv',
#  'sby9.csv',
#  'lombok4.csv',
#  'lombok5.csv',
#  'lombok6.csv',
#  'lombok7.csv',
#  'lombok8.csv',
#  'lombok9.csv',
#  'medan4.csv',
#  'medan5.csv',
#  'medan6.csv',
#  'medan8.csv',
#  'medan7.csv',
#  'medan9.csv',
#  'semarang4.csv',
#  'semarang6.csv',
#  'semarang5.csv',
#  'semarang8.csv',
# ...

# %%
directory = 'gabungan_final'
path = os.path.join(gab_address, directory)
os.mkdir(path)
print("Direktori '%s'" % directory)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-21-120263ea3b79> in <module>()
#       1 directory = 'gabungan_final'
#       2 path = os.path.join(gab_address, directory)
# ----> 3 os.mkdir(path)
#       4 print("Direktori '%s'" % directory)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/scrapping data/gabungan/gabungan_final'

# %%
os.chdir(gab_address)
os.getcwd()
# Out:
# '/content/drive/MyDrive/scrapping data/gabungan'

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('jakarta*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("jakarta.csv", index=False)

# %%
jakarta = 'jakarta.csv'
jakarta = pd.read_csv(jakarta)
jakarta.head()
# Out:
#                                          hfpxzc href                  qBF1Pd  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  https://www.google.com/maps/place/Jakarta+Hist...  Jakarta History Museum
# 3  https://www.google.com/maps/place/Faunaland+An...         Faunaland Ancol
# 4  https://www.google.com/maps/place/Srengseng+Ci...   Srengseng City Forest
#
#   MW4etd     UY7F9 W4Efsd            W4Efsd 2  \
# 0    NaN       NaN    NaN                 NaN
# 1    NaN       NaN    NaN                 NaN
# 2    4.6  (20,176)      ·  Tourist attraction
# 3    4.5   (3,044)      ·  Tourist attraction
# 4    4.3   (8,135)      ·  Tourist attraction
#
#                                             W4Efsd 4  \
# 0                                                NaN
# 1                                                NaN
# 2                        Jalan Taman Fatahillah No.1
# ...

# %%
jakarta.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
jakarta.head()
# Out:
#                                               Source                   Place  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  https://www.google.com/maps/place/Jakarta+Hist...  Jakarta History Museum
# 3  https://www.google.com/maps/place/Faunaland+An...         Faunaland Ancol
# 4  https://www.google.com/maps/place/Srengseng+Ci...   Srengseng City Forest
#
#   Rating Jumlah review W4Efsd                Type  \
# 0    NaN           NaN    NaN                 NaN
# 1    NaN           NaN    NaN                 NaN
# 2    4.6      (20,176)      ·  Tourist attraction
# 3    4.5       (3,044)      ·  Tourist attraction
# 4    4.3       (8,135)      ·  Tourist attraction
#
#                                              Address  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
jakarta = jakarta.drop(columns=['W4Efsd', 'W4Efsd 9','Status_1','Status_2','FQ2IWe src','Jn12ke src','ah5Ghc 3','W6VQef', 'ah5Ghc 2','W4Efsd 3', 'W4Efsd 5','fontBodyMedium'])
jakarta.head()
# Out:
#                                               Source                   Place  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  https://www.google.com/maps/place/Jakarta+Hist...  Jakarta History Museum
# 3  https://www.google.com/maps/place/Faunaland+An...         Faunaland Ancol
# 4  https://www.google.com/maps/place/Srengseng+Ci...   Srengseng City Forest
#
#   Rating Jumlah review                Type  \
# 0    NaN           NaN                 NaN
# 1    NaN           NaN                 NaN
# 2    4.6      (20,176)  Tourist attraction
# 3    4.5       (3,044)  Tourist attraction
# 4    4.3       (8,135)  Tourist attraction
#
#                                              Address  \
# 0                                                NaN
# 1                                                NaN
# 2                        Jalan Taman Fatahillah No.1
# ...

# %%
jakarta.fillna('None', inplace=True)
jakarta.drop(jakarta.index[0:2], inplace=True)
jakarta.head()
# Out:
#                                               Source                   Place  \
# 2  https://www.google.com/maps/place/Jakarta+Hist...  Jakarta History Museum
# 3  https://www.google.com/maps/place/Faunaland+An...         Faunaland Ancol
# 4  https://www.google.com/maps/place/Srengseng+Ci...   Srengseng City Forest
# 5  https://www.google.com/maps/place/Wisata+Sunga...  Wisata Sungai Kota Tua
# 6  https://www.google.com/maps/place/Museum+Bank+...   Museum Bank Indonesia
#
#   Rating Jumlah review                Type  \
# 2    4.6      (20,176)  Tourist attraction
# 3    4.5       (3,044)  Tourist attraction
# 4    4.3       (8,135)  Tourist attraction
# 5    4.5       (1,281)  Tourist attraction
# 6    4.7       (9,536)  Tourist attraction
#
#                                              Address  \
# 2                        Jalan Taman Fatahillah No.1
# 3  VRGP+783, Ecovention Building - Ecopark, Jalan...
# 4                            Jl. H. Kelik, RT.8/RW.6
# ...

# %%
jakarta["Kota"]="Jakarta"
jakarta.to_csv("jakarta.csv", index=True)
os.listdir()
jakarta.head()
# Out:
#                                               Source                   Place  \
# 2  https://www.google.com/maps/place/Jakarta+Hist...  Jakarta History Museum
# 3  https://www.google.com/maps/place/Faunaland+An...         Faunaland Ancol
# 4  https://www.google.com/maps/place/Srengseng+Ci...   Srengseng City Forest
# 5  https://www.google.com/maps/place/Wisata+Sunga...  Wisata Sungai Kota Tua
# 6  https://www.google.com/maps/place/Museum+Bank+...   Museum Bank Indonesia
#
#   Rating Jumlah review                Type  \
# 2    4.6      (20,176)  Tourist attraction
# 3    4.5       (3,044)  Tourist attraction
# 4    4.3       (8,135)  Tourist attraction
# 5    4.5       (1,281)  Tourist attraction
# 6    4.7       (9,536)  Tourist attraction
#
#                                              Address  \
# 2                        Jalan Taman Fatahillah No.1
# 3  VRGP+783, Ecovention Building - Ecopark, Jalan...
# 4                            Jl. H. Kelik, RT.8/RW.6
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('sby*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("sby.csv", index=False)

# %%
sby = "sby.csv"
sby = pd.read_csv(sby)
sby.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Jalan+Gula+S...
# 2  https://www.google.com/maps/place/Sanggar+Agun...
# 3  https://www.google.com/maps/place/Ria+Beach+Ke...
# 4  https://www.google.com/maps/place/Hutan+Kota+B...
#
#                       qBF1Pd MW4etd    UY7F9 W4Efsd            W4Efsd 2  \
# 0                        NaN    NaN      NaN    NaN                 NaN
# 1       Jalan Gula Spot Foto    4.5    (548)      ·  Tourist attraction
# 2       Sanggar Agung Temple    4.5  (2,174)      ·  Tourist attraction
# 3         Ria Beach Kenjeran    4.2  (3,772)      ·  Tourist attraction
# 4  Hutan Kota Balas Klumprik    4.3    (662)      ·  Tourist attraction
#
#                 W4Efsd 4 W4Efsd 5                                  W4Efsd 6  \
# 0                    NaN      NaN                                       NaN
# ...

# %%
sby.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
sby.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Jalan+Gula+S...
# 2  https://www.google.com/maps/place/Sanggar+Agun...
# 3  https://www.google.com/maps/place/Ria+Beach+Ke...
# 4  https://www.google.com/maps/place/Hutan+Kota+B...
#
#                        Place Rating Jumlah review W4Efsd                Type  \
# 0                        NaN    NaN           NaN    NaN                 NaN
# 1       Jalan Gula Spot Foto    4.5         (548)      ·  Tourist attraction
# 2       Sanggar Agung Temple    4.5       (2,174)      ·  Tourist attraction
# 3         Ria Beach Kenjeran    4.2       (3,772)      ·  Tourist attraction
# 4  Hutan Kota Balas Klumprik    4.3         (662)      ·  Tourist attraction
#
#                  Address W4Efsd 5                               description  \
# 0                    NaN      NaN                                       NaN
# ...

# %%
sby = sby.drop(columns=['W4Efsd', 'W4Efsd 9','Status_1','Status_2','FQ2IWe src','Jn12ke src','ah5Ghc 3','W6VQef', 'ah5Ghc 2','W4Efsd 3', 'W4Efsd 5','fontBodyMedium'])
sby.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Jalan+Gula+S...
# 2  https://www.google.com/maps/place/Sanggar+Agun...
# 3  https://www.google.com/maps/place/Ria+Beach+Ke...
# 4  https://www.google.com/maps/place/Hutan+Kota+B...
#
#                        Place Rating Jumlah review                Type  \
# 0                        NaN    NaN           NaN                 NaN
# 1       Jalan Gula Spot Foto    4.5         (548)  Tourist attraction
# 2       Sanggar Agung Temple    4.5       (2,174)  Tourist attraction
# 3         Ria Beach Kenjeran    4.2       (3,772)  Tourist attraction
# 4  Hutan Kota Balas Klumprik    4.3         (662)  Tourist attraction
#
#                  Address                               description  \
# 0                    NaN                                       NaN
# 1   QP6Q+9HP, Jalan Gula     Photo spot amid dilapidated buildings
# ...

# %%
sby.fillna('None', inplace=True)
sby.drop(sby.index[0:1], inplace=True)
sby.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Jalan+Gula+S...
# 2  https://www.google.com/maps/place/Sanggar+Agun...
# 3  https://www.google.com/maps/place/Ria+Beach+Ke...
# 4  https://www.google.com/maps/place/Hutan+Kota+B...
# 5  https://www.google.com/maps/place/Suro+and+Boy...
#
#                        Place Rating Jumlah review                Type  \
# 1       Jalan Gula Spot Foto    4.5         (548)  Tourist attraction
# 2       Sanggar Agung Temple    4.5       (2,174)  Tourist attraction
# 3         Ria Beach Kenjeran    4.2       (3,772)  Tourist attraction
# 4  Hutan Kota Balas Klumprik    4.3         (662)  Tourist attraction
# 5       Suro and Boyo Statue    4.6       (4,883)  Tourist attraction
#
#                  Address                               description  \
# 1   QP6Q+9HP, Jalan Gula     Photo spot amid dilapidated buildings
# 2    Jl. Sukolilo No.100  Beachside shrine with dragon decorations
# ...

# %%
sby["Kota"]="Surabaya"
sby.to_csv("sby.csv", index=True)
os.listdir()
sby.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Jalan+Gula+S...
# 2  https://www.google.com/maps/place/Sanggar+Agun...
# 3  https://www.google.com/maps/place/Ria+Beach+Ke...
# 4  https://www.google.com/maps/place/Hutan+Kota+B...
# 5  https://www.google.com/maps/place/Suro+and+Boy...
#
#                        Place Rating Jumlah review                Type  \
# 1       Jalan Gula Spot Foto    4.5         (548)  Tourist attraction
# 2       Sanggar Agung Temple    4.5       (2,174)  Tourist attraction
# 3         Ria Beach Kenjeran    4.2       (3,772)  Tourist attraction
# 4  Hutan Kota Balas Klumprik    4.3         (662)  Tourist attraction
# 5       Suro and Boyo Statue    4.6       (4,883)  Tourist attraction
#
#                  Address                               description  \
# 1   QP6Q+9HP, Jalan Gula     Photo spot amid dilapidated buildings
# 2    Jl. Sukolilo No.100  Beachside shrine with dragon decorations
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('medan*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("medan.csv", index=False)

# %%
medan = "medan.csv"
medan = pd.read_csv(medan)
medan.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Pemandian/da...
# 2  https://www.google.com/maps/place/Kampung+Outb...
# 3  https://www.google.com/maps/place/Taman+Lope+L...
# 4  https://www.google.com/maps/place/Kampung+Wisa...
#
#                                      qBF1Pd MW4etd  UY7F9 W4Efsd  \
# 0                                       NaN    NaN    NaN    NaN
# 1                                 Pemandian    4,1  (716)      ·
# 2              Kampung Outbound Pancur Batu    4,5  (144)      ·
# 3                 Taman Lope Lope Bulu Cina    4,0  (131)      ·
# 4  Kampung Wisata Ramah Anak Belawan Bahari    4,9   (34)      ·
#
#         W4Efsd 2                                    W4Efsd 4 W4Efsd 5  \
# 0            NaN                                         NaN      NaN
# 1  Tujuan Wisata                                    9M68+MGP        ·
# ...

# %%
medan.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
medan.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Pemandian/da...
# 2  https://www.google.com/maps/place/Kampung+Outb...
# 3  https://www.google.com/maps/place/Taman+Lope+L...
# 4  https://www.google.com/maps/place/Kampung+Wisa...
#
#                                       Place Rating Jumlah review W4Efsd  \
# 0                                       NaN    NaN           NaN    NaN
# 1                                 Pemandian    4,1         (716)      ·
# 2              Kampung Outbound Pancur Batu    4,5         (144)      ·
# 3                 Taman Lope Lope Bulu Cina    4,0         (131)      ·
# 4  Kampung Wisata Ramah Anak Belawan Bahari    4,9          (34)      ·
#
#             Type                                     Address W4Efsd 5  \
# 0            NaN                                         NaN      NaN
# ...

# %%
medan = medan.drop(columns=['W4Efsd', 'W4Efsd 9','Status_1','Status_2','FQ2IWe src','Jn12ke src','ah5Ghc 3','W6VQef', 'ah5Ghc 2','W4Efsd 3', 'W4Efsd 5','fontBodyMedium'])
medan.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Pemandian/da...
# 2  https://www.google.com/maps/place/Kampung+Outb...
# 3  https://www.google.com/maps/place/Taman+Lope+L...
# 4  https://www.google.com/maps/place/Kampung+Wisa...
#
#                                       Place Rating Jumlah review  \
# 0                                       NaN    NaN           NaN
# 1                                 Pemandian    4,1         (716)
# 2              Kampung Outbound Pancur Batu    4,5         (144)
# 3                 Taman Lope Lope Bulu Cina    4,0         (131)
# 4  Kampung Wisata Ramah Anak Belawan Bahari    4,9          (34)
#
#             Type                                     Address  \
# 0            NaN                                         NaN
# 1  Tujuan Wisata                                    9M68+MGP
# 2  Tujuan Wisata                                   Jl. Dusun
# ...

# %%
medan.fillna('None', inplace=True)
medan.drop(medan.index[0:1], inplace=True)
medan.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Pemandian/da...
# 2  https://www.google.com/maps/place/Kampung+Outb...
# 3  https://www.google.com/maps/place/Taman+Lope+L...
# 4  https://www.google.com/maps/place/Kampung+Wisa...
# 5  https://www.google.com/maps/place/Central+Park...
#
#                                       Place Rating Jumlah review  \
# 1                                 Pemandian    4,1         (716)
# 2              Kampung Outbound Pancur Batu    4,5         (144)
# 3                 Taman Lope Lope Bulu Cina    4,0         (131)
# 4  Kampung Wisata Ramah Anak Belawan Bahari    4,9          (34)
# 5                 Central Park Zoo & Resort    4,5       (1.789)
#
#             Type                                     Address  \
# 1  Tujuan Wisata                                    9M68+MGP
# 2  Tujuan Wisata                                   Jl. Dusun
# 3  Tujuan Wisata  PH5G+2H8, Jl. Sei Deli, Silalas, Medan Bar
# ...

# %%
medan["Kota"]="Medan"
medan.to_csv("medan.csv", index=True)
os.listdir()
medan.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Pemandian/da...
# 2  https://www.google.com/maps/place/Kampung+Outb...
# 3  https://www.google.com/maps/place/Taman+Lope+L...
# 4  https://www.google.com/maps/place/Kampung+Wisa...
# 5  https://www.google.com/maps/place/Central+Park...
#
#                                       Place Rating Jumlah review  \
# 1                                 Pemandian    4,1         (716)
# 2              Kampung Outbound Pancur Batu    4,5         (144)
# 3                 Taman Lope Lope Bulu Cina    4,0         (131)
# 4  Kampung Wisata Ramah Anak Belawan Bahari    4,9          (34)
# 5                 Central Park Zoo & Resort    4,5       (1.789)
#
#             Type                                     Address  \
# 1  Tujuan Wisata                                    9M68+MGP
# 2  Tujuan Wisata                                   Jl. Dusun
# 3  Tujuan Wisata  PH5G+2H8, Jl. Sei Deli, Silalas, Medan Bar
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('bandung*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("bandung.csv", index=False)

# %%
bandung = "bandung.csv"
bandung = pd.read_csv(bandung)
bandung.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Museum+3D/da...
# 2  https://www.google.com/maps/place/Sarae+Hills/...
# 3  https://www.google.com/maps/place/Vanda+Park/d...
# 4  https://www.google.com/maps/place/Plaza+Cikapu...
#
#                          qBF1Pd MW4etd    UY7F9 W4Efsd            W4Efsd 2  \
# 0                           NaN    NaN      NaN    NaN                 NaN
# 1                     Museum 3D    4.6    (730)      ·  Tourist attraction
# 2                   Sarae Hills    4.5    (609)      ·  Tourist attraction
# 3                    Vanda Park    4.4  (2,929)      ·  Tourist attraction
# 4  Plaza Cikapundung River Spot    4.3  (4,614)      ·  Tourist attraction
#
#                            W4Efsd 4                                  W4Efsd 6  \
# 0                               NaN                                       NaN
# ...

# %%
bandung.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
bandung.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Museum+3D/da...
# 2  https://www.google.com/maps/place/Sarae+Hills/...
# 3  https://www.google.com/maps/place/Vanda+Park/d...
# 4  https://www.google.com/maps/place/Plaza+Cikapu...
#
#                           Place Rating Jumlah review W4Efsd  \
# 0                           NaN    NaN           NaN    NaN
# 1                     Museum 3D    4.6         (730)      ·
# 2                   Sarae Hills    4.5         (609)      ·
# 3                    Vanda Park    4.4       (2,929)      ·
# 4  Plaza Cikapundung River Spot    4.3       (4,614)      ·
#
#                  Type                           Address  \
# 0                 NaN                               NaN
# 1  Tourist attraction  4HXW+CF8, Jalan Doktor Setiabudi
# 2  Tourist attraction     Jl. Pagermaneuh, RT.05/RW./07
# ...

# %%
bandung = bandung.drop(columns=['W4Efsd', 'W4Efsd 9','Status_1','Status_2','FQ2IWe src','Jn12ke src','ah5Ghc 3','W6VQef', 'ah5Ghc 2','W4Efsd 3', 'W4Efsd 5','fontBodyMedium'])
bandung.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Museum+3D/da...
# 2  https://www.google.com/maps/place/Sarae+Hills/...
# 3  https://www.google.com/maps/place/Vanda+Park/d...
# 4  https://www.google.com/maps/place/Plaza+Cikapu...
#
#                           Place Rating Jumlah review                Type  \
# 0                           NaN    NaN           NaN                 NaN
# 1                     Museum 3D    4.6         (730)  Tourist attraction
# 2                   Sarae Hills    4.5         (609)  Tourist attraction
# 3                    Vanda Park    4.4       (2,929)  Tourist attraction
# 4  Plaza Cikapundung River Spot    4.3       (4,614)  Tourist attraction
#
#                             Address                               description  \
# 0                               NaN                                       NaN
# ...

# %%
bandung.fillna('None', inplace=True)
bandung.drop(bandung.index[0:1], inplace=True)
bandung.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Museum+3D/da...
# 2  https://www.google.com/maps/place/Sarae+Hills/...
# 3  https://www.google.com/maps/place/Vanda+Park/d...
# 4  https://www.google.com/maps/place/Plaza+Cikapu...
# 5  https://www.google.com/maps/place/Taman+Maluku...
#
#                           Place Rating Jumlah review                Type  \
# 1                     Museum 3D    4.6         (730)  Tourist attraction
# 2                   Sarae Hills    4.5         (609)  Tourist attraction
# 3                    Vanda Park    4.4       (2,929)  Tourist attraction
# 4  Plaza Cikapundung River Spot    4.3       (4,614)  Tourist attraction
# 5                  Taman Maluku    4.5       (1,081)  Tourist attraction
#
#                                    Address  \
# 1         4HXW+CF8, Jalan Doktor Setiabudi
# 2            Jl. Pagermaneuh, RT.05/RW./07
# 3                         Jl. Merdeka No.9
# ...

# %%
bandung["Kota"]="Bandung"
bandung.to_csv("bandung.csv", index=True)
os.listdir()
bandung.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Museum+3D/da...
# 2  https://www.google.com/maps/place/Sarae+Hills/...
# 3  https://www.google.com/maps/place/Vanda+Park/d...
# 4  https://www.google.com/maps/place/Plaza+Cikapu...
# 5  https://www.google.com/maps/place/Taman+Maluku...
#
#                           Place Rating Jumlah review                Type  \
# 1                     Museum 3D    4.6         (730)  Tourist attraction
# 2                   Sarae Hills    4.5         (609)  Tourist attraction
# 3                    Vanda Park    4.4       (2,929)  Tourist attraction
# 4  Plaza Cikapundung River Spot    4.3       (4,614)  Tourist attraction
# 5                  Taman Maluku    4.5       (1,081)  Tourist attraction
#
#                                    Address  \
# 1         4HXW+CF8, Jalan Doktor Setiabudi
# 2            Jl. Pagermaneuh, RT.05/RW./07
# 3                         Jl. Merdeka No.9
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('bali*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("bali.csv", index=False)

# %%
bali = "bali.csv"
bali = pd.read_csv(bali)
bali.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Tegenungan+W...
# 2  https://www.google.com/maps/place/Mandala+Suci...
# 3  https://www.google.com/maps/place/Waterbom+Bal...
# 4  https://www.google.com/maps/place/Taman+Nasion...
#
#                       qBF1Pd MW4etd     UY7F9 W4Efsd       W4Efsd 2  \
# 0                        NaN    NaN       NaN    NaN            NaN
# 1       Tegenungan Waterfall    4,3  (21.592)      ·  Tujuan Wisata
# 2   Mandala Suci Wenara Wana    4,5  (34.238)      ·  Tujuan Wisata
# 3              Waterbom Bali    4,7   (9.939)      ·  Tujuan Wisata
# 4  Taman Nasional Bali Barat    4,5   (2.867)      ·  Tujuan Wisata
#
#                                  W4Efsd 4 W4Efsd 5  \
# 0                                     NaN      NaN
# 1                          Jl. Ir. Sutami        ·
# 2                       Jl. Monkey Forest        ·
# ...

# %%
bali.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
bali.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Tegenungan+W...
# 2  https://www.google.com/maps/place/Mandala+Suci...
# 3  https://www.google.com/maps/place/Waterbom+Bal...
# 4  https://www.google.com/maps/place/Taman+Nasion...
#
#                        Place Rating Jumlah review W4Efsd           Type  \
# 0                        NaN    NaN           NaN    NaN            NaN
# 1       Tegenungan Waterfall    4,3      (21.592)      ·  Tujuan Wisata
# 2   Mandala Suci Wenara Wana    4,5      (34.238)      ·  Tujuan Wisata
# 3              Waterbom Bali    4,7       (9.939)      ·  Tujuan Wisata
# 4  Taman Nasional Bali Barat    4,5       (2.867)      ·  Tujuan Wisata
#
#                                   Address W4Efsd 5  \
# 0                                     NaN      NaN
# 1                          Jl. Ir. Sutami        ·
# 2                       Jl. Monkey Forest        ·
# ...

# %%
bali = bali.drop(columns=['W4Efsd', 'W4Efsd 9','Status_1','Status_2','FQ2IWe src','Jn12ke src','W6VQef', 'ah5Ghc 2','W4Efsd 3', 'W4Efsd 5','fontBodyMedium'])
bali.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Tegenungan+W...
# 2  https://www.google.com/maps/place/Mandala+Suci...
# 3  https://www.google.com/maps/place/Waterbom+Bal...
# 4  https://www.google.com/maps/place/Taman+Nasion...
#
#                        Place Rating Jumlah review           Type  \
# 0                        NaN    NaN           NaN            NaN
# 1       Tegenungan Waterfall    4,3      (21.592)  Tujuan Wisata
# 2   Mandala Suci Wenara Wana    4,5      (34.238)  Tujuan Wisata
# 3              Waterbom Bali    4,7       (9.939)  Tujuan Wisata
# 4  Taman Nasional Bali Barat    4,5       (2.867)  Tujuan Wisata
#
#                                   Address  \
# 0                                     NaN
# 1                          Jl. Ir. Sutami
# 2                       Jl. Monkey Forest
# 3                       Jl. Kartika Plaza
# ...

# %%
bali.fillna('None', inplace=True)
bali.drop(bali.index[0:1], inplace=True)

bali.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Tegenungan+W...
# 2  https://www.google.com/maps/place/Mandala+Suci...
# 3  https://www.google.com/maps/place/Waterbom+Bal...
# 4  https://www.google.com/maps/place/Taman+Nasion...
# 5  https://www.google.com/maps/place/Bukit+Campuh...
#
#                        Place Rating Jumlah review           Type  \
# 1       Tegenungan Waterfall    4,3      (21.592)  Tujuan Wisata
# 2   Mandala Suci Wenara Wana    4,5      (34.238)  Tujuan Wisata
# 3              Waterbom Bali    4,7       (9.939)  Tujuan Wisata
# 4  Taman Nasional Bali Barat    4,5       (2.867)  Tujuan Wisata
# 5             Bukit Campuhan    4,5       (2.104)  Tujuan Wisata
#
#                                   Address  \
# 1                          Jl. Ir. Sutami
# 2                       Jl. Monkey Forest
# 3                       Jl. Kartika Plaza
# 4  Cagar alam untuk spesies burung langka
# ...

# %%
bali["Kota"]="Bali"
bali.to_csv("bali.csv", index=True)
os.listdir()
bali.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Tegenungan+W...
# 2  https://www.google.com/maps/place/Mandala+Suci...
# 3  https://www.google.com/maps/place/Waterbom+Bal...
# 4  https://www.google.com/maps/place/Taman+Nasion...
# 5  https://www.google.com/maps/place/Bukit+Campuh...
#
#                        Place Rating Jumlah review           Type  \
# 1       Tegenungan Waterfall    4,3      (21.592)  Tujuan Wisata
# 2   Mandala Suci Wenara Wana    4,5      (34.238)  Tujuan Wisata
# 3              Waterbom Bali    4,7       (9.939)  Tujuan Wisata
# 4  Taman Nasional Bali Barat    4,5       (2.867)  Tujuan Wisata
# 5             Bukit Campuhan    4,5       (2.104)  Tujuan Wisata
#
#                                   Address  \
# 1                          Jl. Ir. Sutami
# 2                       Jl. Monkey Forest
# 3                       Jl. Kartika Plaza
# 4  Cagar alam untuk spesies burung langka
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('semarang*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("semarang.csv", index=False)

# %%
semarang = "semarang.csv"
semarang = pd.read_csv(semarang)
semarang.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Diponegoro+P...
# 2  https://www.google.com/maps/place/Semarang+Con...
# 3  https://www.google.com/maps/place/Air+Terjun+S...
# 4  https://www.google.com/maps/place/Anjungan+Kot...
#
#                               qBF1Pd MW4etd    UY7F9 W4Efsd       W4Efsd 2  \
# 0                                NaN    NaN      NaN    NaN            NaN
# 1                    Diponegoro Park    4,5    (865)      ·  Tujuan Wisata
# 2  Semarang Contemporary Art Gallery    4,6  (1.126)      ·  Tujuan Wisata
# 3                Air Terjun Semirang    4,4    (912)      ·  Tujuan Wisata
# 4             Anjungan Kota Semarang    4,5     (74)      ·  Tujuan Wisata
#
#                       W4Efsd 4                                W4Efsd 6  \
# 0                          NaN                                     NaN
# ...

# %%
semarang.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
semarang.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Diponegoro+P...
# 2  https://www.google.com/maps/place/Semarang+Con...
# 3  https://www.google.com/maps/place/Air+Terjun+S...
# 4  https://www.google.com/maps/place/Anjungan+Kot...
#
#                                Place Rating Jumlah review W4Efsd  \
# 0                                NaN    NaN           NaN    NaN
# 1                    Diponegoro Park    4,5         (865)      ·
# 2  Semarang Contemporary Art Gallery    4,6       (1.126)      ·
# 3                Air Terjun Semirang    4,4         (912)      ·
# 4             Anjungan Kota Semarang    4,5          (74)      ·
#
#             Type                      Address  \
# 0            NaN                          NaN
# 1  Tujuan Wisata   XCR8+WM3, Jl. Sultan Agung
# 2  Tujuan Wisata  Jl. Taman Srigunting No.5-6
# 3  Tujuan Wisata                 Loket wisata
# ...

# %%
semarang = semarang.drop(columns=['W4Efsd', 'W4Efsd 9','Status_1','Status_2','FQ2IWe src','Jn12ke src','W6VQef','W4Efsd 3', 'W4Efsd 5','fontBodyMedium'])
semarang.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Diponegoro+P...
# 2  https://www.google.com/maps/place/Semarang+Con...
# 3  https://www.google.com/maps/place/Air+Terjun+S...
# 4  https://www.google.com/maps/place/Anjungan+Kot...
#
#                                Place Rating Jumlah review           Type  \
# 0                                NaN    NaN           NaN            NaN
# 1                    Diponegoro Park    4,5         (865)  Tujuan Wisata
# 2  Semarang Contemporary Art Gallery    4,6       (1.126)  Tujuan Wisata
# 3                Air Terjun Semirang    4,4         (912)  Tujuan Wisata
# 4             Anjungan Kota Semarang    4,5          (74)  Tujuan Wisata
#
#                        Address                             description  \
# 0                          NaN                                     NaN
# ...

# %%
semarang.fillna('None', inplace=True)
semarang.drop(semarang.index[0:1], inplace=True)
semarang.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Diponegoro+P...
# 2  https://www.google.com/maps/place/Semarang+Con...
# 3  https://www.google.com/maps/place/Air+Terjun+S...
# 4  https://www.google.com/maps/place/Anjungan+Kot...
# 5  https://www.google.com/maps/place/Taman+Budaya...
#
#                                Place Rating Jumlah review           Type  \
# 1                    Diponegoro Park    4,5         (865)  Tujuan Wisata
# 2  Semarang Contemporary Art Gallery    4,6       (1.126)  Tujuan Wisata
# 3                Air Terjun Semirang    4,4         (912)  Tujuan Wisata
# 4             Anjungan Kota Semarang    4,5          (74)  Tujuan Wisata
# 5           Taman Budaya Raden Saleh    4,4       (3.101)  Tujuan Wisata
#
#                        Address                             description  \
# 1   XCR8+WM3, Jl. Sultan Agung     Ruang hijau di bundaran lalu lintas
# ...

# %%
semarang["Kota"]="Semarang"
semarang.to_csv("semarang.csv", index=True)
semarang
# Out:
#                                                  Source  \
# 1     https://www.google.com/maps/place/Diponegoro+P...
# 2     https://www.google.com/maps/place/Semarang+Con...
# 3     https://www.google.com/maps/place/Air+Terjun+S...
# 4     https://www.google.com/maps/place/Anjungan+Kot...
# 5     https://www.google.com/maps/place/Taman+Budaya...
# ...                                                 ...
# 4566                                               None
# 4567                                               None
# 4568                                               None
# 4569                                               None
# 4570                                               None
#
#                                   Place Rating Jumlah review           Type  \
# 1                       Diponegoro Park    4,5         (865)  Tujuan Wisata
# 2     Semarang Contemporary Art Gallery    4,6       (1.126)  Tujuan Wisata
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('lombok*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("lombok.csv", index=False)

# %%
lombok = "lombok.csv"
lombok = pd.read_csv(lombok)
lombok.head()
# Out:
#                                          hfpxzc href  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Bukit+Merese...
# 2  https://www.google.com/maps/place/Wisata+di+Lo...
# 3  https://www.google.com/maps/place/Air+Terjun+B...
# 4  https://www.google.com/maps/place/Sade+Village...
#
#                                    qBF1Pd MW4etd    UY7F9 W4Efsd  \
# 0                                     NaN    NaN      NaN    NaN
# 1  Bukit Merese Lombok (Kuta Lombok Hill)    4,7  (5.116)      ·
# 2                        Wisata di Lombok    4,5    (113)      ·
# 3               Air Terjun Benang Kelambu    4,5  (1.880)      ·
# 4                            Sade Village    4,6  (6.400)      ·
#
#         W4Efsd 2                                     W4Efsd 4 W4Efsd 5  \
# 0            NaN                                          NaN      NaN
# 1  Tujuan Wisata                              Jl. Kuta Lombok        ·
# ...

# %%
lombok.rename(columns = {'qBF1Pd' : 'Place', 'hfpxzc href': 'Source', 'MW4etd' : 'Rating', 'UY7F9' : 'Jumlah review', 'W4Efsd 2' : 'Type', 'W4Efsd 4': 'Address', 'W4Efsd 6' : 'description', 'W4Efsd 7': 'Status_1', 'W4Efsd 8': 'Status_2','ah5Ghc':'Komentar' }, inplace = True)
lombok.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Bukit+Merese...
# 2  https://www.google.com/maps/place/Wisata+di+Lo...
# 3  https://www.google.com/maps/place/Air+Terjun+B...
# 4  https://www.google.com/maps/place/Sade+Village...
#
#                                     Place Rating Jumlah review W4Efsd  \
# 0                                     NaN    NaN           NaN    NaN
# 1  Bukit Merese Lombok (Kuta Lombok Hill)    4,7       (5.116)      ·
# 2                        Wisata di Lombok    4,5         (113)      ·
# 3               Air Terjun Benang Kelambu    4,5       (1.880)      ·
# 4                            Sade Village    4,6       (6.400)      ·
#
#             Type                                      Address W4Efsd 5  \
# 0            NaN                                          NaN      NaN
# 1  Tujuan Wisata                              Jl. Kuta Lombok        ·
# ...

# %%
lombok = lombok.drop(columns=['Status_1','Status_2','W4Efsd', 'W4Efsd 5','FQ2IWe src','Jn12ke src', 'W6VQef','W4Efsd 3','fontBodyMedium'])
lombok.head()
# Out:
#                                               Source  \
# 0                                                NaN
# 1  https://www.google.com/maps/place/Bukit+Merese...
# 2  https://www.google.com/maps/place/Wisata+di+Lo...
# 3  https://www.google.com/maps/place/Air+Terjun+B...
# 4  https://www.google.com/maps/place/Sade+Village...
#
#                                     Place Rating Jumlah review           Type  \
# 0                                     NaN    NaN           NaN            NaN
# 1  Bukit Merese Lombok (Kuta Lombok Hill)    4,7       (5.116)  Tujuan Wisata
# 2                        Wisata di Lombok    4,5         (113)  Tujuan Wisata
# 3               Air Terjun Benang Kelambu    4,5       (1.880)  Tujuan Wisata
# 4                            Sade Village    4,6       (6.400)  Tujuan Wisata
#
#                                        Address  description  \
# 0                                          NaN          NaN
# ...

# %%
lombok.fillna('None', inplace=True)
lombok.drop(lombok.index[0:1], inplace=True)
lombok.head()
# Out:
#                                               Source  \
# 1  https://www.google.com/maps/place/Bukit+Merese...
# 2  https://www.google.com/maps/place/Wisata+di+Lo...
# 3  https://www.google.com/maps/place/Air+Terjun+B...
# 4  https://www.google.com/maps/place/Sade+Village...
# 5  https://www.google.com/maps/place/Air+Terjun+S...
#
#                                     Place Rating Jumlah review           Type  \
# 1  Bukit Merese Lombok (Kuta Lombok Hill)    4,7       (5.116)  Tujuan Wisata
# 2                        Wisata di Lombok    4,5         (113)  Tujuan Wisata
# 3               Air Terjun Benang Kelambu    4,5       (1.880)  Tujuan Wisata
# 4                            Sade Village    4,6       (6.400)  Tujuan Wisata
# 5                 Air Terjun Sendang Gile    4,6         (114)  Tujuan Wisata
#
#                                        Address  description  \
# 1                              Jl. Kuta Lombok  Buka 24 jam
# ...

# %%
lombok["Kota"]="Lombok"
lombok.to_csv("lombok.csv", index=True)
lombok
# Out:
#                                                  Source  \
# 1     https://www.google.com/maps/place/Bukit+Merese...
# 2     https://www.google.com/maps/place/Wisata+di+Lo...
# 3     https://www.google.com/maps/place/Air+Terjun+B...
# 4     https://www.google.com/maps/place/Sade+Village...
# 5     https://www.google.com/maps/place/Air+Terjun+S...
# ...                                                 ...
# 1184  https://www.google.com/maps/place/Kabupaten+Lo...
# 1185  https://www.google.com/maps/place/Makam+Wali+N...
# 1186  https://www.google.com/maps/place/Wisata+Alam+...
# 1187  https://www.google.com/maps/place/Happy+Wisata...
# 1188  https://www.google.com/maps/place/Lombok+Wonde...
#
#                                        Place Rating Jumlah review  \
# 1     Bukit Merese Lombok (Kuta Lombok Hill)    4,7       (5.116)
# 2                           Wisata di Lombok    4,5         (113)
# 3                  Air Terjun Benang Kelambu    4,5       (1.880)
# ...

# %%
#check duplicate data
semarang.drop_duplicates(subset='Source', keep = False, inplace=True)
semarang.to_csv('semarang.csv', index=True)
semarang.head()

jakarta.drop_duplicates(subset='Source', keep = False, inplace=True)
jakarta.to_csv('jakarta.csv', index=True)
jakarta.head()

bali.drop_duplicates(subset='Source', keep = False, inplace=True)
bali.to_csv('bali.csv', index=True)
bali.head()

lombok.drop_duplicates(subset='Source', keep = False, inplace=True)
lombok.to_csv('lombok.csv', index=True)
lombok.head()

bandung.drop_duplicates(subset='Source', keep = False, inplace=True)
bandung.to_csv('bandung.csv', index=True)
bandung.head()

medan.drop_duplicates(subset='Source', keep = False, inplace=True)
medan.to_csv('medan.csv', index=True)
medan.head()

sby.drop_duplicates(subset='Source', keep = False, inplace=True)
sby.to_csv('sby.csv', index=True)
sby.head()
# Out:
#                                                Source  \
# 21  https://www.google.com/maps/place/Religious+To...
# 22  https://www.google.com/maps/place/Taman+Persah...
# 23  https://www.google.com/maps/place/Siola+Suraba...
# 24  https://www.google.com/maps/place/Red+Bridge/d...
# 25  https://www.google.com/maps/place/Taman+Baruna...
#
#                        Place Rating Jumlah review                Type  \
# 21  Religious Tourism MAmpel    4.7         (128)  Tourist attraction
# 22        Taman Persahabatan    4.6         (995)  Tourist attraction
# 23     Siola Surabaya Museum    4.6       (6,535)  Tourist attraction
# 24                Red Bridge    4.5       (2,252)  Tourist attraction
# 25          Taman Barunawati    4.3         (500)  Tourist attraction
#
#                                Address  \
# 21              Jl. Ampel Masjid No.53
# 22                  Jl. Sulawesi No.67
# 23                   Tunjungan St No.1
# 24             Kembang Jepun St No.192
# ...

# %%
#move the file to 'gabungan_final' directory
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/medan.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/medan.csv")
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/semarang.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/semarang.csv")
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/jakarta.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/jakarta.csv")
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/bandung.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/bandung.csv")
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/lombok.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/lombok.csv")
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/bali.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/bali.csv")
shutil.move("/content/drive/MyDrive/scrapping data/gabungan/sby.csv", "/content/drive/MyDrive/scrapping data/gabungan/gabungan_final/sby.csv")

# %%
os.chdir('/content/drive/MyDrive/scrapping data/gabungan/gabungan_final')

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/scrapping data/gabungan/gabungan_final'

# %%
os.listdir()
# Out:
# ['jakarta.csv',
#  'sby.csv',
#  'medan.csv',
#  'bandung.csv',
#  'bali.csv',
#  'semarang.csv',
#  'lombok.csv']

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("gabungan_semua.csv", index=False)

# %%
gabungan = 'gabungan_semua.csv'
gabungan =pd.read_csv(gabungan)
gabungan.head()
# Out:
#    Unnamed: 0                                             Source  \
# 0           2  https://www.google.com/maps/place/Jakarta+Hist...
# 1           3  https://www.google.com/maps/place/Faunaland+An...
# 2           4  https://www.google.com/maps/place/Srengseng+Ci...
# 3           5  https://www.google.com/maps/place/Wisata+Sunga...
# 4           6  https://www.google.com/maps/place/Museum+Bank+...
#
#                     Place Rating Jumlah review                Type  \
# 0  Jakarta History Museum    4.6      (20,176)  Tourist attraction
# 1         Faunaland Ancol    4.5       (3,044)  Tourist attraction
# 2   Srengseng City Forest    4.3       (8,135)  Tourist attraction
# 3  Wisata Sungai Kota Tua    4.5       (1,281)  Tourist attraction
# 4   Museum Bank Indonesia    4.7       (9,536)  Tourist attraction
#
#                                              Address  \
# 0                        Jalan Taman Fatahillah No.1
# 1  VRGP+783, Ecovention Building - Ecopark, Jalan...
# ...

# %%
gabungan = gabungan.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Source.1', 'Place.1', 'Rating.1', 'Jumlah review.1', 'Type.1', 'Address.1', 'description.1', 'Komentar.1'])
gabungan
# Out:
#                                                  Source  \
# 0     https://www.google.com/maps/place/Jakarta+Hist...
# 1     https://www.google.com/maps/place/Faunaland+An...
# 2     https://www.google.com/maps/place/Srengseng+Ci...
# 3     https://www.google.com/maps/place/Wisata+Sunga...
# 4     https://www.google.com/maps/place/Museum+Bank+...
# ...                                                 ...
# 1089  https://www.google.com/maps/place/Air+Terjun+G...
# 1090  https://www.google.com/maps/place/Alun+Alun+Ta...
# 1091  https://www.google.com/maps/place/Air+Terjun+G...
# 1092  https://www.google.com/maps/place/Tereng+Kunin...
# 1093  https://www.google.com/maps/place/Objek+Wisata...
#
#                           Place Rating Jumlah review                Type  \
# 0        Jakarta History Museum    4.6      (20,176)  Tourist attraction
# 1               Faunaland Ancol    4.5       (3,044)  Tourist attraction
# ...

# %%
gabungan.to_csv("gabungan_semua.csv", index=True)
gabungan
# Out:
#                                                  Source  \
# 0     https://www.google.com/maps/place/Jakarta+Hist...
# 1     https://www.google.com/maps/place/Faunaland+An...
# 2     https://www.google.com/maps/place/Srengseng+Ci...
# 3     https://www.google.com/maps/place/Wisata+Sunga...
# 4     https://www.google.com/maps/place/Museum+Bank+...
# ...                                                 ...
# 1089  https://www.google.com/maps/place/Air+Terjun+G...
# 1090  https://www.google.com/maps/place/Alun+Alun+Ta...
# 1091  https://www.google.com/maps/place/Air+Terjun+G...
# 1092  https://www.google.com/maps/place/Tereng+Kunin...
# 1093  https://www.google.com/maps/place/Objek+Wisata...
#
#                           Place Rating Jumlah review                Type  \
# 0        Jakarta History Museum    4.6      (20,176)  Tourist attraction
# 1               Faunaland Ancol    4.5       (3,044)  Tourist attraction
# ...

# %%
#values = ['biro', 'dinas', 'kantor', 'tour', 'paket', 'travel', 'pt', 'travelling', 'perusahaan', 'kebudayaan']
#temp = [x for x in gabungan['Type'] if x.lower() in values]
#print(temp)
# Out:
# []

# %%
#values = ['biro', 'biro wisata', 'dinas kebudayaan', 'kantor Perusahaan', 'tour', 'paket wisata', 'travelling', 'pt']
#gabungan = gabungan[gabungan['Type'].isin(values) == False]
#gabungan=gabungan[gabungan["Type"] not in values]
gabungan1 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Tujuan Wisata'].index)
#gabungan1
#print(gabungan1)
gabungan2 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Tourist attraction'].index)
gabungan3 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Kafe'].index)
gabungan4 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Taman'].index)
gabungan5 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Area Rekreasi Alam'].index)
gabungan6 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Park'].index)
gabungan7 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Kebun Binatang'].index)
gabungan8 = gabungan.drop(gabungan.loc[gabungan['Type'] != 'Kafetaria'].index)
gabungan7
# Out:
#                                                 Source  \
# 75   https://www.google.com/maps/place/Jakarta+Aqua...
# 755  https://www.google.com/maps/place/Bali+Safari+...
#
#                          Place Rating Jumlah review            Type  \
# 75   Jakarta Aquarium & Safari    4,5          (67)  Kebun Binatang
# 755  Bali Safari & Marine Park    4,4      (15.161)  Kebun Binatang
#
#                                                Address  \
# 75   Neo Soho @Podomoro City Floor LG 101 - LGM 101...
# 755            Jl. Prof. Dr. Ida Bagus Mantra No.km 19
#
#                                 description  \
# 75                                     None
# 755  Pilihan untuk melihat satwa & main air
#
#                                         Komentar     Kota
# 75   "Tempat yang menarik dan menyenangkan untuk  Jakarta
# 755                                            "     Bali

# %%
gabungan1.to_csv("gabungan_final1.csv", index=True)
gabungan2.to_csv("gabungan_final2.csv", index=True)
gabungan3.to_csv("gabungan_final3.csv", index=True)
gabungan4.to_csv("gabungan_final4.csv", index=True)
gabungan5.to_csv("gabungan_final5.csv", index=True)
gabungan6.to_csv("gabungan_final6.csv", index=True)
gabungan7.to_csv("gabungan_final7.csv", index=True)
gabungan7.to_csv("gabungan_final8.csv", index=True)                  
extension = 'csv'
all_filenames = [i for i in glob.glob('gabungan_final*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv.to_csv("gabungan_all.csv", index=False)
gabungan_all = 'gabungan_all.csv'
gabungan_all = pd.read_csv(gabungan_all)
#gabungan.to_csv("gabungan_semua.csv", index=True)
#gabungan
gabungan_all
# Out:
#      Unnamed: 0                                             Source  \
# 0            59  https://www.google.com/maps/place/'@Jktgoodgui...
# 1            61  https://www.google.com/maps/place/Wisata+Serib...
# 2            62  https://www.google.com/maps/place/Tempat+Santa...
# 3            63  https://www.google.com/maps/place/Kaai%E2%80%9...
# 4            64  https://www.google.com/maps/place/FEBRI+%26+IF...
# ..          ...                                                ...
# 442          33  https://www.google.com/maps/place/Taman+Burung...
# 443          75  https://www.google.com/maps/place/Jakarta+Aqua...
# 444         755  https://www.google.com/maps/place/Bali+Safari+...
# 445          75  https://www.google.com/maps/place/Jakarta+Aqua...
# 446         755  https://www.google.com/maps/place/Bali+Safari+...
#
#                                   Place Rating Jumlah review            Type  \
# 0                         @Jktgoodguide   None          None   Tujuan Wisata
# ...

# %%
#gabungan = 'gabungan_semua.csv'
#gabungan = pd.read_csv(gabungan)
gabungan_all.drop_duplicates(subset='Source', keep = False, inplace=True)
gabungan_all = gabungan_all.drop(columns=['Unnamed: 0'])
gabungan_all.to_csv('gabungan_all.csv', index=True)
gabungan_all
# Out:
#                                                 Source  \
# 0    https://www.google.com/maps/place/'@Jktgoodgui...
# 1    https://www.google.com/maps/place/Wisata+Serib...
# 2    https://www.google.com/maps/place/Tempat+Santa...
# 3    https://www.google.com/maps/place/Kaai%E2%80%9...
# 4    https://www.google.com/maps/place/FEBRI+%26+IF...
# ..                                                 ...
# 438  https://www.google.com/maps/place/Masok/data=!...
# 439  https://www.google.com/maps/place/Taman+Pantai...
# 440  https://www.google.com/maps/place/Explore+Wisa...
# 441  https://www.google.com/maps/place/Desa+Wisata+...
# 442  https://www.google.com/maps/place/Taman+Burung...
#
#                                   Place Rating Jumlah review  \
# 0                         @Jktgoodguide   None          None
# 1             Wisata Seribu PolisiTidur    4,2           (6)
# 2    Tempat Santai Pinggir Kali Gusuran   None          None
# ...

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/scrapping data/gabungan/gabungan_final'
